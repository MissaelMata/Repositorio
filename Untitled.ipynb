# %% [markdown]
# # Mata Martinez Missael
# ## Practica 1

# %% [markdown]
# En esta practica se desarrollara la 1era practica del curso de Minería de datos.
#
# El primer paso es importar las librerias para desarrollar la practica:

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# Para leer el archivo que vamos a utilizar:

# %%
df = pd.read_csv("unclean_data1.csv")

# %% [markdown]
# Para reconocer los simbolos extraños:

# %%
df = pd.read_csv("unclean_data1.csv",encoding='utf8')

# %% [markdown]
# Para que muestre los primeros 5 registros de la lista:

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# Para que muestre los ultimos 5 registros de la lista:

# %%
df.tail()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 9                    25000  301956980         321795.0
# ...

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %% [markdown]
# Renombraremos las columnas, por el siguientes metodo:

# %%
df.rename(columns = {'movie_title':'Titulo'})
# Out:
#                                           Titulo  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# Para saber que tipo de dato es cada columna:

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %% [markdown]
# Para saber el tipo de dato de una columna en especifico:

# %%
df['imdb_score'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Para normalizar los datos que contiene cada columna en especifico:

# %%
df.duration.astype("float")
# Out:
# 0     178.0
# 1       NaN
# 2     148.0
# 3       NaN
# 4     132.0
# 5     156.0
# 6       NaN
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: duration, dtype: float64

# %% [markdown]
# Para extraer datos de una columna:

# %%
df.duration.unique()
# Out:
# array([178.,  nan, 148., 132., 156., 141., 153., 183., 169., 106., 151.])

# %% [markdown]
# Para agrupar los datos de una columna y mostrarla:

# %%
Duracion = df[df['duration']=='Duracion']
CalIMDB = df[df['imdb_score']=='CalIMDB']
AnoTitulo = df[df['title_year.1']=='AnoTitulo']

Duracion.to_csv('Solo_Duracion.csv', index=False)
CalIMDB.to_csv('Solo_Duracion.csv', index=False)
AnoTitulo.to_csv('Solo_Duracion.csv', index=False)

# %% [markdown]
# Se menciona arriba la seleccion de 3 columnas para ser convertidas a clases.
#
# Para encontrar el valor en un dataframe comparandolas con otra columna debemos hacer esto:

# %%
Duracion_vs_CalIMDB = df.loc[df.duration == 'Duracion']

# %% [markdown]
# Para reemplazar datos o el nombre de las columnas, hacemos lo siguiente:

# %%
df.movie_title.replace(to_replace = dict(Clase_1 = 1, Clase_2 = 0), inplace = True)
df.replace()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# Arriba se puede utilizar solo los datos "object", no se puede hacer con datos flotantes y strings

# %% [markdown]
# Para quitar una columna que no ocupemos, usaremos este comando:

# %%
df.drop('ACTOR_1_facebook_likes',axis = 1 )
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# ### Pregunta de interes:
# ####  ¿Para que me puede servir estas agrupaciones para la practica siguiente?
# Serviria como un repaso para poder saber que comando utilizar en caso de que la practica siguiente pida una instruccion de un paso que ya debemos saber.
#
#
# Para detectar cada dato nulo en la lista:

# %%
df.isnull()
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %% [markdown]
# Con el comando siguiente, se explicara en cada columna como actuan los datoos nulos y saber si hay en cada una.

# %%
df.isnull().any()
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %% [markdown]
# Para poder saber cuantos valores nulos hay en cada columna:

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %% [markdown]
# ### Pregunta de interés
# #### Importancia del analisis previo de los datos antes de iniciar las modificaciones
# Se debe tener en cuenta que es muy importante saber estos metodos ya que nos serviran para uso de siguientes actividades previas, el saber quitar espacios, simbolos, datos basura, datos nulos entre otras muchas cosas seran aplicables en algun momento, con esto tambien tomando en cuenta el saber utilizar las herramientas de agrupacion o clasificacion son vitales o incluso mas importante que lo anterior mencionado.

# %% [markdown]
# Para llenar los datos nulos con ceros:

# %%
data_frame_0 = df.fillna(0)

# %% [markdown]
# Para eliminar datos nulos de cada columna:

# %%
df_drop = df.dropna()

# %% [markdown]
# Para eliminar columnas con datos nulos:

# %%
df_drop_column = df.dropna(axis=1)

# %%
df.dropna()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %% [markdown]
# ### Puntos extras
# #### df.dropna()
# Es una palabra reservada de la biblioteca de pandas, la cual su funcion es quitar valores perdidos, ya sean nulos, basura  o  falsos.
#
# #### df.astype()
# Es un comando para especificar un dtype, estos se incluyen datos tipo fecha y
