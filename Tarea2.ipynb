# %% [markdown]
# # Mata Martinez Missael
# ## Practica 2

# %% [markdown]
# Se importan las librerias primero:

# %%
import pandas as pd

# %% [markdown]
# Retomando la practica anterior, se tendra que repasar los metodos pasados:

# %%
df = pd.read_csv("w-data.csv")

# %%
df.shape
# Out:
# (569, 33)

# %% [markdown]
# Muestra los primeros 5 datos:

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# Muestra los ultimos 5 datos:

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %% [markdown]
# Otra manera de ver las columnas:

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# Saber que tipo es cada columna:

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [markdown]
# Encontrar valores nulos:

# %%
df.isnull()
# Out:
#         id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False        False         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# ..     ...        ...          ...           ...             ...        ...
# 564  False      False        False         False           False      False
# 565  False      False        False         False           False      False
# 566  False      False        False         False           False      False
# 567  False      False        False         False           False      False
# 568  False      False        False         False           False      False
#
# ...

# %%
df.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# ...

# %% [markdown]
# En pocas palabras, no hay valores nulos.

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# Una vez repasando los metodos de la primera practica, se arrancara con la segunda actividad. Tomando en cuenta un pequeño ejemplo de como utilizar un diccionario:

# %%
data = {'Nombre': ['Missael', 'Arturo', 'Alicia', 'Alex', 'Daniela'], 
        'Edad': [22, 21, 25, 22, 22], 
        '1er_Parcial': [80, 60, 98, 69, 80],
        '2do_Parcial': [78, 76, 90, 62, 80]}
df2 = pd.DataFrame(data, columns = ['Nombre', 'Edad', '1er_Parcial', '2do_Parcial'])
df2
# Out:
#     Nombre  Edad  1er_Parcial  2do_Parcial
# 0  Missael    22           80           78
# 1   Arturo    21           60           76
# 2   Alicia    25           98           90
# 3     Alex    22           69           62
# 4  Daniela    22           80           80

# %% [markdown]
# Añadiremos un ejemplo de los comandos principales de la libería de pandas:

# %%
df['area_mean'].sum()
# Out:
# 372631.9

# %% [markdown]
# Arriba se muestra la suma de todas los registros de una columna. Despues se muestra un ejemplo de la calculacion de un promedio:

# %%
df['area_mean'].mean()
# Out:
# 654.8891036906857

# %%
df.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %% [markdown]
# Añadiendo un ejemplo de como los datos se relacionan con .corr() Sobrando una columna con datos nulos los borraremos:

# %%
df_drop_column = df.dropna(axis=1)

# %%
df_drop_column
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
import matplotlib as plt
# %matplotlib inline

# %%
df_drop_column.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# A continuacion se mostro como se añadio la nueva base de datos sin datos nulos.

# %%
df_drop_column.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df_drop_column.plot.bar()

# %% [markdown]
# Debido a la sobre saturacion de datos agregados de forma grafica, se puede apreciar de la siguiente manera.

# %%
df_drop_column['area_worst'].value_counts().plot.bar()

# %% [markdown]
# Con las librerias de matplot se pueden crear varias tablas de las cuales se pueden mostrar varios histogramas, una ventaja de esta librería, es poder visualizar diferentes tipos de graficas, mostrando un ejemplo de cada una con la base de datos, por ejemplo, en la grafica de arriba se pueden mostrar graficos con una o mas variables.

# %% [markdown]
# Para poder apreciar solo 10 datos en una grafica:

# %%
df_drop_column['area_worst'].value_counts().head(10).plot.bar()

# %%
(df_drop_column['area_worst'].value_counts().head(10) / len(df_drop_column)).plot.bar()

# %%
df_drop_column['area_se'].value_counts().sort_index().plot.bar()

# %%
df_drop_column['area_se'].value_counts().sort_index().head(10).plot.line()

# %%
df_drop_column[df_drop_column['area_se'] < 200]['area_se'].head(10).plot.hist()

# %% [markdown]
# En la grafica anterior se mostro un histograma en el cual solo añade 10 registros para evitar la sobre saturacion. Analiza la frecuencia mas alta de los datos.

# %%
df_drop_column['area_se'].value_counts().sort_index().plot.area()

# %%
df_drop_column[df_drop_column['area_se'] < 100].sample(100).plot.scatter(x='radius_mean', y='area_mean')

# %% [markdown]
# En la grafica anterior se utilizo la grafica de Scatter plot, se trata de graficar datos bi-variantes en los cuales consiste en tratar de relacionarse unos con otros. Mostrando un pequeño ejemplo mas simple:

# %%
df_drop_column[df_drop_column['radius_mean'] < 100].sample(100).plot.scatter(x='radius_mean', y='area_mean')

# %%
df_drop_column[df_drop_column['radius_mean'] < 100].plot.hexbin(x='radius_mean', y='area_mean', gridsize=7)

# %% [markdown]
# Una manera mas visibles y tratar de notar un poco mas la diferencia en la correlacion de los datos, dandonos como referencia a un cluster.

# %%
df_drop_column.head(10).plot.bar(stacked=True)

# %% [markdown]
# Con el stacked plot es muy similiar a la grafica normal de plot, variando que las columnas se grafican arriba de otra, por sobre carga de datos no se logra apreciar muy bien.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling

# %%
sns.countplot(df_drop_column['area_se'])

# %% [markdown]
# Con este metodo, se puede graficar de manera mas eficaz, se elimina el ruido con ayuda de la libreria de seaborn.

# %%
sns.kdeplot(df_drop_column.query('area_se < 200').area_se)

# %% [markdown]
# Señalando en la siguiente grafica, se visualiza con la grafica de sort_index() con una sola columna.

# %%
df_drop_column[df_drop_column['area_se'] < 200]['area_se'].value_counts().sort_index().plot.line()

# %%
sns.kdeplot(df_drop_column[df_drop_column['area_se'] < 200].loc[:, ['area_se', 'texture_mean']].dropna().sample(200))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %% [markdown]
# Otra manera de graficar un histograma

# %%
sns.jointplot(x='area_se', y='texture_mean', data=df_drop_column[df_drop_column['area_se'] < 100])

# %% [markdown]
# Si se quiere ver de manera de cluster:

# %%
sns.jointplot(x='area_se', y='texture_mean', data=df_drop_column[df_drop_column['area_se'] < 100], kind='hex', 
              gridsize=20)

# %%
dfbox = df_drop_column[df_drop_column.area_se.isin(df_drop_column.area_se.value_counts().head(5).index)]

sns.boxplot(
    x='area_se',
    y='texture_mean',
    data=dfbox
)

# %% [markdown]
# En la grafica de violin se muestra los datos de las columnas uilizadas en la anterior grafica.

# %%
sns.violinplot(
    x='area_se',
    y='texture_mean',
    data=df_drop_column[df_drop_column.area_se.isin(df_drop_column.area_se.value_counts().head(5).index)]
)

# %%
sns.pairplot(df_drop_column[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean']])

# %% [markdown]
# Arriba se muestra varias graficas de manera en que ciertas columnas muestren la frecuencia mas comun.

# %%
sns.lmplot(x='radius_mean', y='perimeter_mean', hue='diagnosis', 
           data=df.loc[df['diagnosis'].isin(['B', 'M'])], 
           fit_reg=False)

# %%
m = plt.hist(df[df["diagnosis"] == "M"].radius_mean,bins=30,fc = (1,0,0,0.5),label = "Maligno")
b = plt.hist(df[df["diagnosis"] == "B"].radius_mean,bins=30,fc = (0,1,0,0.5),label = "Benigno")
plt.legend()
plt.xlabel("Valor de la media del radio")
plt.ylabel("Frecuencia")
plt.title("Histograma")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   import sys

# %% [markdown]
# Mas muestras de las varias de muchas representaciones de graficar datos.

# %%
mdata = pd.melt(df,id_vars = "diagnosis",value_vars = ['radius_mean', 'texture_mean'])
plt.figure(figsize = (15,10))
sns.boxplot(x = "variable", y = "value", hue="diagnosis",data= mdata)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
f,ax=plt.subplots(figsize = (17,17))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   import sys

# %% [markdown]
# Al final de esto, se observa como todos los datos de la base de datos seleccionada se tratan de correlacionar entre si.

# %%
report = pandas_profiling.ProfileReport(df)
report.to_file("report.html")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %% [markdown]
# Finalizando la practica, cuando se haya echo la tabla, existira la opcion de imprimir un reporte en el cual se muestre todos los datos de nuestra base de datos y que tipo es cada uno.
